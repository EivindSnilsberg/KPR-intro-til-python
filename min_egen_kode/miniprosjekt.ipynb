# %%
#payment

#Proof of payment

cart = []

def main():
    print("Velkommen til McEndre")


    items ={
        "1":("Burger",99),
        "2":("Stor Burger",199),
        "3":("Brus",39)
    }

    userinput = ""
    tablenr = slectTable()
    takeout = False
    

    while userinput != "q":

        print("Du valgte bord nr:", tablenr)
        printMenu()
        userinput = input ("Velg: ")
        addProduct(userinput, items)

    total = calcukateTotal(cart)

    print("Du handlet for", total, "kr")
    print("Takk for at du handlet hos McEndre")


def slectTable():
    eatHere = input("Skal du spise her? j/n")
    if eatHere == "j":
        return int(input("Oppgi bordnr:"))
        
    elif eatHere == "n":
        return 0
    
    else:
        slectTable()


def printMenu(product):

    for item in products

    print("Hva ønsker du?")
    print("1 - Burger")
    print("2 - Stor burger")
    print("3 - Burs")
    print("q - Avbryt")


def addProduct(product, items):
    productName, productPrice = items[product]
        
    if product == "1":
        if product in items:
            qty = int(input("Hvor mange ønsker du?"))
        cart.append((productName, productPrice,qty))
        print(f"La tukk {qty} x {productName} ({productPrice} kr/stk).")    

    elif product == "2":
        if product in items:
            qty = int(input("Hvor mange ønsker du?"))
        cart.append((productName, productPrice,qty))
        print(f"La tukk {qty} x {productName} ({productPrice} kr/stk).") 
            

    elif product == "3":
        if product in items:
            qty = int(input("Hvor mange ønsker du?"))
        cart.append((productName, productPrice,qty))
        print(f"La tukk {qty} x {productName} ({productPrice} kr/stk).") 

    else:
        addProduct(product, items)
        

def calcukateTotal(cart):
    total = 0
    for productNames, price, qty in cart:
        total += price * qty
    return total


main()
# Out:
# Velkommen til McEndre
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 88
#      85     elif product != "q":
#      86         print("Varen eksisterer ikkke")
# ---> 88 main()
#
# Cell In[10], line 24, in main()
#      17 items ={
#      18     "1":("Burger",99),
#      19     "2":("Stor Burger",199),
#      20     "3":("Brus",39)
#      21 }
#      23 userinput = ""
# ---> 24 tablenr = slectTable()
#      25 takeout = False
#      28 while userinput != "q":
#
# Cell In[10], line 41, in slectTable()
#      39 eatHere = input("Skal du spise her? j/n")
#      40 if eatHere == "j":
# ---> 41     return tablenr == int(input("Oppgi bordnr:"))
#      43 elif eatHere == "n":
#      44     return 0
#
# NameError: name 'tablenr' is not defined
